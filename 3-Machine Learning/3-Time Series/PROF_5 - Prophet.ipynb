# %% [markdown]
# ## Librería de Facebook Prophet
# Para este notebook vamos a probar la librería de Facebook llamada Prophet. Esta librería sirve para hacer predicciones con series temporales. Abstrae bastante del proceso de creación del modelo y es bastante sencilla de usar.
#
# Lo primero, instalamos

# %%
#!pip install fbprophet

# %%
import pandas as pd
import numpy as np
from fbprophet import Prophet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-9c2aab3d9697> in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from fbprophet import Prophet
#
# ModuleNotFoundError: No module named 'fbprophet'

# %%
df = pd.read_csv('data/Bike_Sharing_Demand.csv')

df = df.rename(columns={'datetime': 'ds', 'count': 'y'})
df = df[['ds', 'y']]
df.set_index('ds', inplace=True)
print(len(df))
df.head()
# Out:
# 10886
#                       y
# ds
# 2011-01-01 00:00:00  16
# 2011-01-01 01:00:00  40
# 2011-01-01 02:00:00  32
# 2011-01-01 03:00:00  13
# 2011-01-01 04:00:00   1

# %%
df.plot();
df[0:24*4].plot();

# %%
train = df[0:8000]
test = df[8000:]

# %%
validate = df[['ds','y']].tail(48)

df.drop(df[['ds','y']].tail(48).index,inplace=True)

train = df[['ds','y']]

# %%
m = Prophet(yearly_seasonality=False)

m.fit(train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-39de59ce60d1> in <module>
# ----> 1 m = Prophet(yearly_seasonality=False)
#       2
#       3 m.fit(train)
#
# NameError: name 'Prophet' is not defined
