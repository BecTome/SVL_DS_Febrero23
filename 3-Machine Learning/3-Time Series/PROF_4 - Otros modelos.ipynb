# %% [markdown]
# ## Otros modelos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Cargamos datos

# %%
df = pd.read_csv('data/jj.csv', index_col=0)
print(len(df))
df.head()
# Out:
# 84
#             data
# date
# 1960-01-01  0.71
# 1960-04-01  0.63
# 1960-07-02  0.85
# 1960-10-01  0.44
# 1961-01-01  0.61

# %%
df.plot();

# %% [markdown]
# ### Preparamos las features del dataset

# %%
for i in range(12,0,-1):
    df['t-'+str(i)] = df['data'].shift(i)
df.dropna(inplace=True)

# %%
df['data'].plot();

# %%
df
# Out:
#              data       t-12       t-11       t-10        t-9        t-8  \
# date
# 1963-01-01   0.83   0.710000   0.630000   0.850000   0.440000   0.610000
# 1963-04-02   0.80   0.630000   0.850000   0.440000   0.610000   0.690000
# 1963-07-02   1.00   0.850000   0.440000   0.610000   0.690000   0.920000
# 1963-10-01   0.77   0.440000   0.610000   0.690000   0.920000   0.550000
# 1964-01-01   0.92   0.610000   0.690000   0.920000   0.550000   0.720000
# ...           ...        ...        ...        ...        ...        ...
# 1979-10-01   9.99   6.840000   9.540000  10.260000   9.540000   8.729999
# 1980-01-01  16.20   9.540000  10.260000   9.540000   8.729999  11.880000
# 1980-04-01  14.67  10.260000   9.540000   8.729999  11.880000  12.060000
# 1980-07-02  16.02   9.540000   8.729999  11.880000  12.060000  12.150000
# 1980-10-01  11.61   8.729999  11.880000  12.060000  12.150000   8.910000
#
#               t-7    t-6    t-5    t-4    t-3    t-2    t-1
# date
# 1963-01-01   0.69   0.92   0.55   0.72   0.77   0.92   0.60
# 1963-04-02   0.92   0.55   0.72   0.77   0.92   0.60   0.83
# 1963-07-02   0.55   0.72   0.77   0.92   0.60   0.83   0.80
# 1963-10-01   0.72   0.77   0.92   0.60   0.83   0.80   1.00
# 1964-01-01   0.77   0.92   0.60   0.83   0.80   1.00   0.77
# ...           ...    ...    ...    ...    ...    ...    ...
# 1979-10-01  11.88  12.06  12.15   8.91  14.04  12.96  14.85
# 1980-01-01  12.06  12.15   8.91  14.04  12.96  14.85   9.99
# 1980-04-01  12.15   8.91  14.04  12.96  14.85   9.99  16.20
# 1980-07-02   8.91  14.04  12.96  14.85   9.99  16.20  14.67
# 1980-10-01  14.04  12.96  14.85   9.99  16.20  14.67  16.02
#
# [72 rows x 13 columns]

# %% [markdown]
# ### Dividimos en train test

# %%
X = df.iloc[:, 1:].values
Y = df.iloc[:, 0].values

X_train = X[:60]
X_test = X[60:]
y_train = Y[:60]
y_test = Y[60:]

print("Shape X_train:", X_train.shape)
print("Shape X_test:", X_test.shape)
print("Shape y_train:", y_train.shape)
print("Shape y_test:", y_test.shape)
# Out:
# Shape X_train: (60, 12)
# Shape X_test: (12, 12)
# Shape y_train: (60,)
# Shape y_test: (12,)

# %% [markdown]
# ### Creamos el árbol de decisión

# %%
# Decision Tree Regresion Model

from sklearn.tree import DecisionTreeRegressor

# Create a decision tree regression model with default arguments
tree = DecisionTreeRegressor()  # max-depth not set

# Fit the model to the training features and targets
tree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
from sklearn.metrics import mean_squared_error

print("MSE:", mean_squared_error(tree.predict(X_test), y_test))
print("RMSE:", np.sqrt(mean_squared_error(tree.predict(X_test), y_test)))
# Out:
# MSE: 16.123050000000003
# RMSE: 4.0153517903167595

# %% [markdown]
# ### Representamos las predicciones

# %%
def prediction(model, x_test):
    preds = x_test[0]
    preds_out = []
    for i in range(len(X_test)):
        pred = model.predict([preds])[0]
        preds_out.append(pred)

        preds2 = np.array([preds[1:]]) # Quitamos t-12, ya no se usa
        
        '''
        Concatenamos la nueva, es decir, el nuevo t-1
        '''
        preds = np.c_[preds2, np.array([pred])][0]
    return preds_out

# %%
preds = prediction(tree, X_test)
preds
# Out:
# [10.26, 9.54, 9.54, 8.28, 9.54, 9.54, 9.54, 9.54, 10.26, 9.54, 9.54, 9.54]

# %%
print("MSE:", mean_squared_error(y_test, preds))
print("RMSE:", np.sqrt(mean_squared_error(y_test, preds)))
# Out:
# MSE: 15.36705
# RMSE: 3.9200829072865284

# %%
plt.plot(y_test);
plt.plot(prediction(tree, X_test), color='red');

# %% [markdown]
# ### Probamos con un RandomForest

# %%
# Random Forest
from sklearn.ensemble import RandomForestRegressor

# Create the random forest model and fit to the training data
rfr = RandomForestRegressor(n_estimators=200)  # n_estimators is the number of trees in forest
rfr.fit(X_train, y_train)

print("MSE:", mean_squared_error(rfr.predict(X_test), y_test))
print("RMSE:", np.sqrt(mean_squared_error(rfr.predict(X_test), y_test)))
# Out:
# MSE: 16.258526417039395
# RMSE: 4.032186307332462

# %%
preds = prediction(rfr, X_test)

print("MSE:", mean_squared_error(y_test, preds))
print("RMSE:", np.sqrt(mean_squared_error(y_test, preds)))
# Out:
# MSE: 16.22766295946752
# RMSE: 4.028357352503315

# %% [markdown]
# ## Probamos también una regresión lineal

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()  # n_estimators is the number of trees in forest
lin_reg.fit(X_train, y_train)

print("MSE:", mean_squared_error(lin_reg.predict(X_test), y_test))
print("RMSE:", np.sqrt(mean_squared_error(lin_reg.predict(X_test), y_test)))
# Out:
# MSE: 1.3371420639448248
# RMSE: 1.156348591016059

# %%
preds = prediction(lin_reg, X_test)

print("MSE:", mean_squared_error(y_test, preds))
print("RMSE:", np.sqrt(mean_squared_error(y_test, preds)))
# Out:
# MSE: 2.21791665161966
# RMSE: 1.489267152534984

# %%
plt.plot(y_test);
plt.plot(lin_reg.predict(X_test), color='red');

# %%
y_test
# Out:
# array([11.88, 12.06, 12.15,  8.91, 14.04, 12.96, 14.85,  9.99, 16.2 ,
#        14.67, 16.02, 11.61])

# %%
plt.plot(y_test);
plt.plot(prediction(lin_reg, X_test), color='red');
