# %% [markdown]
# ## Ejercicios de Matplotlib

# %% [markdown]
# 1. Importa pyplot, numpy y pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# Out:
# C:\Users\alber\AppData\Local\Temp\ipykernel_12492\2290088659.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# 2. Activa matplotlib de forma estática

# %% [markdown]
# 3. Sabemos que podemos pintar gráficas de dos formas: la figura incluye los ejes o teniendo figura y ejes por separado.
# Usando solo una figura, usa numpy para los valores del eje X entre 0 y 5. Pinta dos gráficas en dos cajas distintas, a la izquierda una recta con pendiente positiva de 3 que pase por (0,0) y a la derecha una recta con pendiente negativa de 3 que pase por (0,-5). Elige la precisión en el eje X que desees.

# %%
x = np.linspace(0, 5, 50)

plt.figure(figsize=(8, 3))

plt.subplot(1, 2, 1)
plt.plot(x, 3*x)

plt.subplot(1, 2, 2)
plt.plot(x, -3*x-5)

# %%
x = np.linspace(0, 5, 50)

fig, ax = plt.subplots(1, 2, figsize=(5, 2))
ax[0].plot(x, 3*x)
ax[1].plot(x, -3*x-5)

plt.tight_layout()

# %% [markdown]
# 4. Fija el eje X entre 0 y 5 y el eje Y entre -15 y 15

# %%
x = np.linspace(0, 5, 50)

plt.figure(figsize=(8, 3))

plt.subplot(1, 2, 1)
plt.plot(x, 3*x)
plt.xlim(0, 5)
plt.ylim(-15, 15)

plt.subplot(1, 2, 2)
plt.plot(x, -3*x-5)
plt.xlim(0, 5)
plt.ylim(-15, 15)
# Out:
# (-15.0, 15.0)

# %%
fig, ax = plt.subplots(1, 2)

ax[0].plot(x, 3*x)
ax[1].plot(x, -3*x-5)

# ax[0].set_xlim(0, 5)
# ax[0].set_ylim(-15, 15)

# ax[1].set_xlim(0, 5)
# ax[1].set_ylim(-15, 15)

for axx in ax:
    axx.set_xlim(0, 5)
    axx.set_ylim(-15, 15)

# %%
x = np.linspace(0, 5)

fig, ax = plt.subplots(1, 2)
ax[0].plot(x, 3*x)
ax[1].plot(x, -3*x-5)

# plt.tight_layout()

for axx in ax:
    axx.set_xlim([0, 5])
    axx.set_ylim([-15, 15])

# %% [markdown]
# 5. Llama al eje X "eje X", al eje Y "eje Y" y pon de títulos "recta sube" y "recta baja". Muestra dos etiquetas de ejeX pero solo una de eje Y.

# %%
x = np.linspace(0, 5)

fig, ax = plt.subplots(1, 2)
ax[0].plot(x, 3*x)
ax[1].plot(x, -3*x-5)
# plt.tight_layout()

ax[0].set_title("Recta sube")
ax[1].set_title("Recta baja")

for axx in ax:
    axx.set_xlim([0, 5])
    axx.set_ylim([-15, 15])

    axx.set_xlabel("Eje x")
    axx.set_ylabel("Eje y")

ax[1].set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# Vamos a pintar lo mismo pero accediendo directamente a los ejes

# %% [markdown]
# 6. Usando una figura Y EJES POR SEPARADO, usa numpy para los valores del eje X entre 0 y 5. Pinta dos gráficas en dos cajas distintas, a la izquierda una recta con pendiente positiva de 3 que pase por (0,0) y a la derecha una recta con pendiente negativa de 3 que pase por (0,-5). Elige la precisión en el eje X que desees.

# %%
# obtén solo la figura y los ejes y mira el resultado

x = np.linspace(0, 5)

fig = plt.figure()

plt.subplot(1, 2, 1)
plt.plot(x, 3*x)
plt.title("Recta Sube")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.xlim(0, 5)
plt.ylim(-15, 15)

plt.subplot(1, 2, 2)
plt.plot(x, -3*x-5)
plt.title("Recta Baja")
plt.xlabel("Eje X")
plt.xlim(0, 5)
plt.ylim(-15, 15)
# Out:
# (-15.0, 15.0)

# %%
# basándote en el código previo, cambia solo la manipulación de los ejes
# recuerda que hay unos métodos que su nombre cambia un poco

# %% [markdown]
# 7. Existen distintos modelos de gráficas.

# %% [markdown]
# Crea una lista de coordenadas X: 20, 22, 24, 26, 28
# Crea una lista de coordenadas Y: 5, 15, -5, 20, 5
# Usa un gráfico de barras colocadas en X con alturas Y

# %%
x = np.arange(20, 29, 2)
y = np.array([5, 15, -5, 20, 5])

plt.bar(x=x, height=y, alpha=.8, color='lightblue')
plt.title("Mi primer grafico de barras")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.grid();

# %% [markdown]
# 8. Crea un gráfico de barras. Pintamos la altura de un grupo de amigos, cada barra representa a una persona. Ana mide 160 cm, Luis mide 180 cm, Pedro mide 175 cm, Sofía mide 190 cm, Carmen mide 170 cm. Las barras serán verdes.
# Consejo: si no vas a tener que manipular especialmente los ejes, es más sencillo dejarlos dentro de la figura.

# %%
x = ['Ana', 'Luis', 'Pedro', 'Sofia', 'Carmen']
y = [160, 180, 175, 190, 170]

plt.bar(x=x, height=y, color='green');

# %%
fig, ax = plt.subplots()
ax.bar(x=x, height=y, color='green');

# %% [markdown]
# 9. Basándote en el gráfico anterior, escribe encima de cada barra la altura de cada amigo.
# Pista: usa un bucle que lea cada barra de barplot = plt.bar(x,y)
# bar tiene los métodos get_height(), get_x(), get_width()
# plt.text(x,y,valor, va='bottom')

# %%
fig, ax = plt.subplots()
barplot = ax.bar(x,y, color='green')

for bar in barplot:
    x_text = bar.get_x() + 1/3*bar.get_width()
    y_text = bar.get_height()
    text = bar.get_height()

    ax.text(x_text, y_text, text, va='bottom')

# %% [markdown]
# 10. Cambia el tamaño de la figura a (3,5)

# %%
fig.set_size_inches(3, 5)
fig

# %%
plt.figure(figsize=(3, 5))
fig

# %% [markdown]
# 11. Basándote en el gráfico anterior, borra la escala del eje Y (ya aparece en la altura)
# Pista: cuando plt.yticks() recibe una lista vacía no pinta el eje Y

# %%
ax.set_yticks([])
fig

# %% [markdown]
# 12. Prueba a hacer el gráfico con las barras en horizontal (no es necesario poner el texto al final de la barra).

# %%
fig, ax = plt.subplots()
bars = ax.barh(y=x, width=y, color='green')
for bar in bars:
    ax.text(bar.get_width(), bar.get_y() + bar.get_height()*0.4, bar.get_width());

# %% [markdown]
# 13. Prueba a invertir los ejes con ax.invert_axis()
# Necesitarás tener los ejes disponibles fuera de la figura

# %%
ax.invert_xaxis()
ax.invert_yaxis()

# %%
fig

# %% [markdown]
# 14. En el último gráfico, cambia el estilo a 'dark_background'

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
with plt.style.context('dark_background'):
    fig, ax = plt.subplots()
    bars = ax.barh(y=x, width=y, color='green')
    for bar in bars:
        ax.text(bar.get_width(), bar.get_y() + bar.get_height()*0.4, bar.get_width())
    ax.grid();

# %% [markdown]
# 15. Vamos a introducir pandas. Crea un DataFrame con las columnas "Year" de valores 2015, 2016, 2017, 2018, 2019 y la columna "Sold_items_A" de valores 1000, 3500, 4000, 5500, 7000

# %%
df = pd.DataFrame({'Year':np.arange(2015, 2020), 'Sold_items_A':[1000, 3500, 4000, 5500, 7000]})
df['Year'] = pd.to_datetime(df['Year'], format='%Y')
df
# Out:
#         Year  Sold_items_A
# 0 2015-01-01          1000
# 1 2016-01-01          3500
# 2 2017-01-01          4000
# 3 2018-01-01          5500
# 4 2019-01-01          7000

# %% [markdown]
# 16. Ahora pintamos un gráfico de línea con las ventas respecto al año. Pon un título y etiquetas en los ejes.
# Cambia el estilo a 'seaborn-white'. La línea debe ser con rayas y verde.

# %%
with plt.style.context('seaborn-white'):
    df.plot(x='Year', y='Sold_items_A', style='g--', 
            title="Ventas anuales 2015-2019", legend=False)
    plt.ylabel("Ventas")

# %% [markdown]
# 17. Otro departamento B ha vendido en esos años 2000, 3100, 5000, 4000, 6000 unidades. Incluye esa columna en el DataFrame y pinta en la misma gráfica las dos líneas. B es una línea punteada y roja. Muestra una leyenda abajo a la derecha.

# %%
df['Sold_items_B'] = [2000, 3100, 5000, 4000, 6000]
df
# Out:
#         Year  Sold_items_A  Sold_items_B
# 0 2015-01-01          1000          2000
# 1 2016-01-01          3500          3100
# 2 2017-01-01          4000          5000
# 3 2018-01-01          5500          4000
# 4 2019-01-01          7000          6000

# %%
with plt.style.context('seaborn-white'):
    df.plot(x='Year', y=['Sold_items_A', 'Sold_items_B'], style=['g--', 'r:'], 
            title="Ventas anuales 2015-2019")
    plt.ylabel("Ventas")
    plt.legend(loc='lower right')

# %% [markdown]
# 18. Haz un scatter del departamento A usando __solo el DataFrame__.
# Pista: el propio DataFrame tiene un método plot.
# df.plot('columna X', 'columna Y', 'kind' = 'scatter)

# %%
with plt.style.context('seaborn-white'):
    df.plot(kind='scatter', x='Year', y='Sold_items_A', 
            title="Ventas anuales 2015-2019")
    plt.ylabel("Ventas")

# %% [markdown]
# 19. Prueba a cambiar kind a 'pie'

# %%
df
# Out:
#         Year  Sold_items_A  Sold_items_B
# 0 2015-01-01          1000          2000
# 1 2016-01-01          3500          3100
# 2 2017-01-01          4000          5000
# 3 2018-01-01          5500          4000
# 4 2019-01-01          7000          6000

# %%
with plt.style.context('seaborn-white'):
    df.plot(kind='pie', x='Year', y='Sold_items_A', 
            title="Ventas anuales 2015-2019",
            labels=df['Sold_items_A'], autopct='%.2f')
    plt.ylabel("Ventas")

# %% [markdown]
# 20. Prueba a quitar la leyenda incluyendo legend igual a False, añade labels y quita la etiqueta en Y

# %%
with plt.style.context('seaborn-white'):
    df.plot(kind='pie', x='Year', y='Sold_items_A', 
            title="Ventas anuales 2015-2019", legend=False,
            labels=df['Sold_items_A'], autopct='%.2f')
    plt.ylabel('')

# %% [markdown]
# 21. Vamos a pintar un histograma

# %%
np.random.seed(1) # cada vez que le pida N números aleatorios, me dará los mismos

mydf = pd.DataFrame({"Altura" : np.random.randint(low=150, high=190, size=300)})

mydf
# Out:
#      Altura
# 0       187
# 1       162
# 2       158
# 3       159
# 4       161
# ..      ...
# 295     177
# 296     151
# 297     168
# 298     180
# 299     182
#
# [300 rows x 1 columns]

# %%
mydf.value_counts().sort_values(ascending=False)
# Out:
# Altura
# 163       14
# 157       13
# 182       13
# 173       12
# 170       11
# 165       10
# 174       10
# 160       10
# 162       10
# 175        9
# 172        9
# 180        9
# 178        9
# 169        8
# 150        8
# 164        8
# 189        8
# 152        7
# 153        7
# 156        7
# 158        7
# 171        7
# 187        7
# 177        7
# 168        7
# 184        6
# 167        6
# 155        6
# 159        6
# 154        6
# 186        5
# 188        5
# 161        5
# 176        5
# 151        5
# 166        5
# 179        4
# 183        4
# 185        4
# 181        1
# dtype: int64

# %% [markdown]
# Pista: https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.plot.html

# %%
# Histogram

mydf.plot(kind='hist', bins=30, rwidth=.9)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %% [markdown]
# Nota: con ax = df.plot()
#
# se pueden poner las etiquetas con
#
# ax.set(xlabel="Bins")

# %% [markdown]
# 22. Contornos de 3D a 2D. Escribe una función que recibiendo x,y devuelva (1 - x / 2 + x ** 5 + y ** 3) * np.exp(-x ** 2 -y ** 2)
#
# Tablero: Tanto x como y van de -3 a 3 y usaremos 256 puntos.
# Usa contourf, con 8 niveles (cortes), una transparencia de 0.75 y un color map de tipo 'jet'.
# Bonus: pinta las líneas de los contornos también de negro

# %%
x = np.linspace(-3, 3, 256)
y = np.linspace(-3, 3, 256)
# full coordinate arrays
xx, yy = np.meshgrid(x, y)

z = (1 - xx / 2 + xx ** 5 + yy ** 3) * np.exp(-xx ** 2 -yy ** 2)

plt.contourf(xx, yy, z)
plt.colorbar()

# %%
np.random.seed(0)
df['Sold_items_C'] = df['Sold_items_B'] * np.random.rand()

# %%
zz
# Out:
# array([[[1097.62700785, 1701.32186217, 2744.06751964, 2195.25401571,
#          3292.88102356],
#         [1097.62700785, 1701.32186217, 2744.06751964, 2195.25401571,
#          3292.88102356],
#         [1097.62700785, 1701.32186217, 2744.06751964, 2195.25401571,
#          3292.88102356],
#         [1097.62700785, 1701.32186217, 2744.06751964, 2195.25401571,
#          3292.88102356],
#         [1097.62700785, 1701.32186217, 2744.06751964, 2195.25401571,
#          3292.88102356]],
#
#        [[1097.62700785, 1701.32186217, 2744.06751964, 2195.25401571,
#          3292.88102356],
#         [1097.62700785, 1701.32186217, 2744.06751964, 2195.25401571,
#          3292.88102356],
#         [1097.62700785, 1701.32186217, 2744.06751964, 2195.25401571,
#          3292.88102356],
#         [1097.62700785, 1701.32186217, 2744.06751964, 2195.25401571,
#          3292.88102356],
#         [1097.62700785, 1701.32186217, 2744.06751964, 2195.25401571,
#          3292.88102356]],
#
#        [[1097.62700785, 1701.32186217, 2744.06751964, 2195.25401571,
#          3292.88102356],
#         [1097.62700785, 1701.32186217, 2744.06751964, 2195.25401571,
#          3292.88102356],
#         [1097.62700785, 1701.32186217, 2744.06751964, 2195.25401571,
#          3292.88102356],
#         [1097.62700785, 1701.32186217, 2744.06751964, 2195.25401571,
#          3292.88102356],
#         [1097.62700785, 1701.32186217, 2744.06751964, 2195.25401571,
#          3292.88102356]],
#
#        [[1097.62700785, 1701.32186217, 2744.06751964, 2195.25401571,
#          3292.88102356],
#         [1097.62700785, 1701.32186217, 2744.06751964, 2195.25401571,
#          3292.88102356],
#         [1097.62700785, 1701.32186217, 2744.06751964, 2195.25401571,
#          3292.88102356],
#         [1097.62700785, 1701.32186217, 2744.06751964, 2195.25401571,
#          3292.88102356],
#         [1097.62700785, 1701.32186217, 2744.06751964, 2195.25401571,
#          3292.88102356]],
#
#        [[1097.62700785, 1701.32186217, 2744.06751964, 2195.25401571,
#          3292.88102356],
#         [1097.62700785, 1701.32186217, 2744.06751964, 2195.25401571,
#          3292.88102356],
#         [1097.62700785, 1701.32186217, 2744.06751964, 2195.25401571,
#          3292.88102356],
#         [1097.62700785, 1701.32186217, 2744.06751964, 2195.25401571,
#          3292.88102356],
#         [1097.62700785, 1701.32186217, 2744.06751964, 2195.25401571,
#          3292.88102356]]])

# %%
z.shape
# Out:
# (5,)

# %%
z = df['Sold_items_C'].values
zz = np.repeat(z, 5).reshape(5, 5).T

# %%
xx, yy = np.meshgrid(df['Sold_items_A'], df['Sold_items_B'])

plt.contourf(xx, yy, zz)
plt.colorbar()

# %%
xx
# Out:
# array([[[1000, 1000, 1000, 1000, 1000],
#         [3500, 3500, 3500, 3500, 3500],
#         [4000, 4000, 4000, 4000, 4000],
#         [5500, 5500, 5500, 5500, 5500],
#         [7000, 7000, 7000, 7000, 7000]],
#
#        [[1000, 1000, 1000, 1000, 1000],
#         [3500, 3500, 3500, 3500, 3500],
#         [4000, 4000, 4000, 4000, 4000],
#         [5500, 5500, 5500, 5500, 5500],
#         [7000, 7000, 7000, 7000, 7000]],
#
#        [[1000, 1000, 1000, 1000, 1000],
#         [3500, 3500, 3500, 3500, 3500],
#         [4000, 4000, 4000, 4000, 4000],
#         [5500, 5500, 5500, 5500, 5500],
#         [7000, 7000, 7000, 7000, 7000]],
#
#        [[1000, 1000, 1000, 1000, 1000],
#         [3500, 3500, 3500, 3500, 3500],
#         [4000, 4000, 4000, 4000, 4000],
#         [5500, 5500, 5500, 5500, 5500],
#         [7000, 7000, 7000, 7000, 7000]],
#
#        [[1000, 1000, 1000, 1000, 1000],
#         [3500, 3500, 3500, 3500, 3500],
#         [4000, 4000, 4000, 4000, 4000],
#         [5500, 5500, 5500, 5500, 5500],
#         [7000, 7000, 7000, 7000, 7000]]], dtype=int64)
