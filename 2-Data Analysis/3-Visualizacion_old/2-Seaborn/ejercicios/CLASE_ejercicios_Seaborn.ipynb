# %%
# ejercicios de Seaborn

# %%
# 1. Importa pandas, pyplot y seaborn

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
#import pandas.util.testing as tm

# %%
# 2. Activa matplotlib de forma estática

# %%
# %matplotlib inline

# %%
# 3. Lee 'Pokemon.csv', lee la primera columna del csv como índice del DataFrame

# %%
df = pd.read_csv('data/Pokemon.csv', encoding='latin1', index_col=0)

# %%
# 4. Mira las primeras filas del dataset para hacerte una idea de los datos cargados

# %%
df.head()
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# #
# 1     45      1      False
# 2     60      2      False
# 3     80      3      False
# 4     65      1      False
# 5     80      2      False

# %%
# 5. Haz un scatter plot con lmplot(), que es el método que pinta una regresión lineal
# Pasa el DataFrame como argumento del método en el parámetro llamado data
# Usa Attack y Defense para el scatter

# %%
sns.lmplot(x='Attack', y='Defense', data=df);

# %%
# Ouissam 0.75
# Kike 0.6
# Nani 0.7
# Selu 0.4
# Mario 0.48

df[['Attack', 'Defense']].corr()
# Out:
#            Attack   Defense
# Attack   1.000000  0.491965
# Defense  0.491965  1.000000

# %% [markdown]
# $$
# y \approx log(x^2)
# $$
#
# $$
# z = exp(y) \approx x^2
# $$
#
# $$
# u = \sqrt{exp(y)} \approx x
# $$

# %%
import numpy as np
sns.pairplot(df.select_dtypes(np.number))

# %%
# 6. No queremos ver la línea recta de la regresión lineal.
# prueba a añadir fit_reg a falso

# %%
sns.lmplot(x='Attack', y='Defense', data=df, fit_reg=False);

# %%
# 7. Vamos a decir qué variable (columna del DataFrame) codifica los colores (hue)
# Que el hue sea el Stage

# %%
df.head(20)
# Out:
#           Name  Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1    Bulbasaur   Grass  Poison    318  45      49       49       65       65
# 2      Ivysaur   Grass  Poison    405  60      62       63       80       80
# 3     Venusaur   Grass  Poison    525  80      82       83      100      100
# 4   Charmander    Fire     NaN    309  39      52       43       60       50
# 5   Charmeleon    Fire     NaN    405  58      64       58       80       65
# 6    Charizard    Fire  Flying    534  78      84       78      109       85
# 7     Squirtle   Water     NaN    314  44      48       65       50       64
# 8    Wartortle   Water     NaN    405  59      63       80       65       80
# 9    Blastoise   Water     NaN    530  79      83      100       85      105
# 10    Caterpie     Bug     NaN    195  45      30       35       20       20
# 11     Metapod     Bug     NaN    205  50      20       55       25       25
# 12  Butterfree     Bug  Flying    395  60      45       50       90       80
# 13      Weedle     Bug  Poison    195  40      35       30       20       20
# 14      Kakuna     Bug  Poison    205  45      25       50       25       25
# 15    Beedrill     Bug  Poison    395  65      90       40       45       80
# 16      Pidgey  Normal  Flying    251  40      45       40       35       35
# 17   Pidgeotto  Normal  Flying    349  63      60       55       50       50
# 18     Pidgeot  Normal  Flying    479  83      80       75       70       70
# 19     Rattata  Normal     NaN    253  30      56       35       25       35
# 20    Raticate  Normal     NaN    413  55      81       60       50       70
#
#     Speed  Stage  Legendary
# #
# 1      45      1      False
# 2      60      2      False
# 3      80      3      False
# 4      65      1      False
# 5      80      2      False
# 6     100      3      False
# 7      43      1      False
# 8      58      2      False
# 9      78      3      False
# 10     45      1      False
# 11     30      2      False
# 12     70      3      False
# 13     50      1      False
# 14     35      2      False
# 15     75      3      False
# 16     56      1      False
# 17     71      2      False
# 18    101      3      False
# 19     72      1      False
# 20     97      2      False

# %%
sns.lmplot(x='Attack', y='Defense', data=df, fit_reg=False, hue='Stage');

# %%
# 8. Limita el eje x entre 20 y 100

# %%
grid = sns.lmplot(x='Attack',
                  y='Defense',
                  data=df,
                  fit_reg=False,
                  hue='Stage')

grid.set(xlim=(20, 100));

# %%
# Recordamos los diagramas de caja

# %% [markdown]
# <img src="../img/boxplot.png">

# %%
# 9. Dibuja un diagrama de cajas con el dataframe

# %%
plt.figure(figsize=(30, 10))
ax = sns.boxplot(data=df)
ax.tick_params('both', labelsize=20);

# %%
# 10. No nos interesan las columnas Total, Stage ni Legendary
# Bórralos del DataFrame y vuelve a dibujar el diagrama de cajas

# %%
df_reducido = df.drop(['Total', 'Stage', 'Legendary'], axis=1)

sns.boxplot(data=df_reducido);

# %%
df_reducido.describe()
# Out:
#                HP      Attack     Defense     Sp. Atk     Sp. Def       Speed
# count  151.000000  151.000000  151.000000  151.000000  151.000000  151.000000
# mean    64.211921   72.549669   68.225166   67.139073   66.019868   68.933775
# std     28.590117   26.596162   26.916704   28.534199   24.197926   26.746880
# min     10.000000    5.000000    5.000000   15.000000   20.000000   15.000000
# 25%     45.000000   51.000000   50.000000   45.000000   49.000000   46.500000
# 50%     60.000000   70.000000   65.000000   65.000000   65.000000   70.000000
# 75%     80.000000   90.000000   84.000000   87.500000   80.000000   90.000000
# max    250.000000  134.000000  180.000000  154.000000  125.000000  140.000000

# %%
# 11. Mira cuántos 'Type 1' diferentes hay en el DataFrame

# %%
df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon'], dtype=object)

# %%
# 12. Quédate del Dataframe solo con los 'Type 1' iguales a 'Grass', 'Fire' o 'Water'

# %%
#df_grass_fire_water = df[((df['Type 1']=='Grass') | (df['Type 1']=='Fire') | (df['Type 1']=='Water'))]
df_grass_fire_water = df[df['Type 1'].isin(['Grass', 'Fire', 'Water'])]

# %%
df_grass_fire_water.shape
# Out:
# (52, 12)

# %%
# 13. Usa un estilo 'whitegrid'

# %%
sns.set_style('whitegrid')

# %%
# 14. Pinta diagramas de violín con el DataFrame
#

# %%
sns.violinplot(x='Type 1', y='Attack', data=df_grass_fire_water);
#sns.violinplot(data=df_grass_fire_water)

# %%
sns.boxplot(x='Type 1', y='Attack', data=df_grass_fire_water);

# %%
# 15. Escribe una lista de colores con valores '#78C850', '#F08030',  '#6890F0'

# %%
pokemon_colores = ['#78C850', '#F08030',  '#6890F0']

# %%
# 16. Pinta de nuevo los diagramas de violín añadiendo esos colores en la paleta (palette)

# %%
sns.violinplot(x='Type 1',
               y='Attack',
               data=df_grass_fire_water,
               palette = pokemon_colores);

# %%
# 17. Con el diagrama de violín vemos la forma de la distribución, pero no sabemos si Grass tiene muchos puntos y Fire tiene muy pocos.
# Para ver esto, usamos el swarmplot.
# Pinta el último diagrama de violines pero con un swarmplot en lugar de un violin

# %%
sns.swarmplot(x='Type 1',
              y='Attack',
              data=df_grass_fire_water,
              palette = pokemon_colores);

# %%
# 18. Queremos ver los violines a la vez que los swarm, los podemos pintar juntos. 
# Elimina los diagramas de caja dentro de los violines con el parámetro inner = None y pon una transparencia de 0.9
# Pon un título con pyplot (como siempre)

# %%
plt.figure(figsize=(10,6))
 
sns.violinplot(x='Type 1',
               y='Attack',
               data=df_grass_fire_water,
               inner=None,
               palette=pokemon_colores)
 
sns.swarmplot(x='Type 1',
              y='Attack',
              data=df_grass_fire_water,
              color='g',
              alpha=0.9) 
 
plt.title('Pokemons');

# %%
# 19. Veamos la función melt() de pandas. Melt toma los valores de varias columnas y los junta todos en una misma columna nueva.
# Dado un DataFrame, melt recibe varios parámetros:
# * qué columnas del DataFrame se quedan igual
# * qué nombres de columnas del dataframe pasan a ser una columna nueva
# * cómo queremos llamar esas nuevas columnas

# Primero recuerda el Dataframe df_grass_fire_water con las primeras 5 filas

# %%
df_grass_fire_water.head()
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# #
# 1     45      1      False
# 2     60      2      False
# 3     80      3      False
# 4     65      1      False
# 5     80      2      False

# %%
# 20. Queremos dejar igual las variables 'Name' y 'Type 1'
# Queremos añadir una columa nueva cuyos valores sean las columnas que queremos apilar y que se llame 'New Column'
# Escribimos df_grass_fire_water.melt(id_vars=['Name', 'Type 1'], value_vars=[...], var_name='New Column')

# %%
df_grass_fire_water.melt(id_vars=['Name', 'Type 1'],
                         value_vars=['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Stage', 'Legendary'],
                         var_name='New Column')
# Out:
#            Name Type 1 New Column  value
# 0     Bulbasaur  Grass         HP     45
# 1       Ivysaur  Grass         HP     60
# 2      Venusaur  Grass         HP     80
# 3    Charmander   Fire         HP     39
# 4    Charmeleon   Fire         HP     58
# ..          ...    ...        ...    ...
# 411    Gyarados  Water  Legendary  False
# 412      Lapras  Water  Legendary  False
# 413    Vaporeon  Water  Legendary  False
# 414     Flareon   Fire  Legendary  False
# 415     Moltres   Fire  Legendary   True
#
# [416 rows x 4 columns]

# %%
values.index
# Out:
# Index(['Type 2', 'Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def',
#        'Speed', 'Stage', 'Legendary'],
#       dtype='object')

# %%
index
# Out:
# ('Moltres', 'Fire')

# %%
df_aux = df_grass_fire_water.copy()
df_aux.set_index(['Name', 'Type 1'], inplace=True)

# dff = pd.DataFrame({'Name':[], 'Type 1':[], 'var_name': [], 'val_name':[]})
dff = pd.DataFrame([])
for (index, values) in df_aux.iterrows():
    # print(index)
    # print(values, end="\n\n")
    # dff_2 = pd.DataFrame({'Name':[], 'Type 1':[], 'var_name': [], 'val_name':[]})
    dff_2['var_name'] = list(values.index)
    dff_2['val_name'] = list(values.values)
    dff_2['Name'] = index[0]
    dff_2['Type 1'] = index[1]
    # print(dff_2)
    dff = pd.concat([dff, dff_2])

dff.head(20)
# Out:
#         Name Type 1   var_name val_name
# 0  Bulbasaur  Grass     Type 2   Poison
# 1  Bulbasaur  Grass      Total      318
# 2  Bulbasaur  Grass         HP       45
# 3  Bulbasaur  Grass     Attack       49
# 4  Bulbasaur  Grass    Defense       49
# 5  Bulbasaur  Grass    Sp. Atk       65
# 6  Bulbasaur  Grass    Sp. Def       65
# 7  Bulbasaur  Grass      Speed       45
# 8  Bulbasaur  Grass      Stage        1
# 9  Bulbasaur  Grass  Legendary    False
# 0    Ivysaur  Grass     Type 2   Poison
# 1    Ivysaur  Grass      Total      405
# 2    Ivysaur  Grass         HP       60
# 3    Ivysaur  Grass     Attack       62
# 4    Ivysaur  Grass    Defense       63
# 5    Ivysaur  Grass    Sp. Atk       80
# 6    Ivysaur  Grass    Sp. Def       80
# 7    Ivysaur  Grass      Speed       60
# 8    Ivysaur  Grass      Stage        2
# 9    Ivysaur  Grass  Legendary    False

# %%
dff.pivot(index=['Name', 'Type 1'], columns='var_name', values='val_name').reset_index()
# Out:
# var_name        Name Type 1 Attack Defense   HP Legendary Sp. Atk Sp. Def  \
# 0           Arcanine   Fire    110      80   90     False     100      80
# 1         Bellsprout  Grass     75      35   50     False      70      30
# 2          Blastoise  Water     83     100   79     False      85     105
# 3          Bulbasaur  Grass     49      49   45     False      65      65
# 4          Charizard   Fire     84      78   78     False     109      85
# 5         Charmander   Fire     52      43   39     False      60      50
# 6         Charmeleon   Fire     64      58   58     False      80      65
# 7           Cloyster  Water     95     180   50     False      85      45
# 8            Dewgong  Water     70      80   90     False      70      95
# 9          Exeggcute  Grass     40      80   60     False      60      45
# 10         Exeggutor  Grass     95      85   95     False     125      65
# 11           Flareon   Fire    130      60   65     False      95     110
# 12             Gloom  Grass     65      70   60     False      85      75
# 13           Goldeen  Water     67      60   45     False      35      50
# 14           Golduck  Water     82      78   80     False      95      80
# 15         Growlithe   Fire     70      45   55     False      70      50
# 16          Gyarados  Water    125      79   95     False      60     100
# 17            Horsea  Water     40      70   30     False      70      25
# 18           Ivysaur  Grass     62      63   60     False      80      80
# 19           Kingler  Water    130     115   55     False      50      50
# 20            Krabby  Water    105      90   30     False      25      25
# 21            Lapras  Water     85      80  130     False      85      95
# 22          Magikarp  Water     10      55   20     False      15      20
# 23            Magmar   Fire     95      57   65     False     100      85
# 24           Moltres   Fire    100      90   90      True     125      85
# 25         Ninetales   Fire     76      75   73     False      81     100
# 26            Oddish  Grass     50      55   45     False      75      65
# 27           Poliwag  Water     50      40   40     False      40      40
# 28         Poliwhirl  Water     65      65   65     False      50      50
# 29         Poliwrath  Water     95      95   90     False      70      90
# 30            Ponyta   Fire     85      55   50     False      65      65
# 31           Psyduck  Water     52      48   50     False      65      50
# 32          Rapidash   Fire    100      70   65     False      80      80
# 33            Seadra  Water     65      95   55     False      95      45
# 34           Seaking  Water     92      65   80     False      65      80
# 35              Seel  Water     45      55   65     False      45      70
# 36          Shellder  Water     65     100   30     False      45      25
# 37           Slowbro  Water     75     110   95     False     100      80
# 38          Slowpoke  Water     65      65   90     False      40      40
# 39          Squirtle  Water     48      65   44     False      50      64
# 40           Starmie  Water     75      85   60     False     100      85
# 41            Staryu  Water     45      55   30     False      70      55
# 42           Tangela  Grass     55     115   65     False     100      40
# 43         Tentacool  Water     40      35   40     False      50     100
# 44        Tentacruel  Water     70      65   80     False      80     120
# 45          Vaporeon  Water     65      60  130     False     110      95
# 46          Venusaur  Grass     82      83   80     False     100     100
# 47        Victreebel  Grass    105      65   80     False     100      70
# 48         Vileplume  Grass     80      85   75     False     110      90
# 49            Vulpix   Fire     41      40   38     False      50      65
# 50         Wartortle  Water     63      80   59     False      65      80
# 51        Weepinbell  Grass     90      50   65     False      85      45
#
# var_name Speed Stage Total    Type 2
# 0           95     2   555       NaN
# 1           40     1   300    Poison
# 2           78     3   530       NaN
# 3           45     1   318    Poison
# 4          100     3   534    Flying
# 5           65     1   309       NaN
# 6           80     2   405       NaN
# 7           70     2   525       Ice
# 8           70     2   475       Ice
# 9           40     1   325   Psychic
# 10          55     2   520   Psychic
# 11          65     2   525       NaN
# 12          40     2   395    Poison
# 13          63     1   320       NaN
# 14          85     2   500       NaN
# 15          60     1   350       NaN
# 16          81     2   540    Flying
# 17          60     1   295       NaN
# 18          60     2   405    Poison
# 19          75     2   475       NaN
# 20          50     1   325       NaN
# 21          60     1   535       Ice
# 22          80     1   200       NaN
# 23          93     1   495       NaN
# 24          90     1   580    Flying
# 25         100     2   505       NaN
# 26          30     1   320    Poison
# 27          90     1   300       NaN
# 28          90     2   385       NaN
# 29          70     3   510  Fighting
# 30          90     1   410       NaN
# 31          55     1   320       NaN
# 32         105     2   500       NaN
# 33          85     2   440       NaN
# 34          68     2   450       NaN
# 35          45     1   325       NaN
# 36          40     1   305       NaN
# 37          30     2   490   Psychic
# 38          15     1   315   Psychic
# 39          43     1   314       NaN
# 40         115     2   520   Psychic
# 41          85     1   340       NaN
# 42          60     1   435       NaN
# 43          70     1   335    Poison
# 44         100     2   515    Poison
# 45          65     2   525       NaN
# 46          80     3   525    Poison
# 47          70     3   490    Poison
# 48          50     3   490    Poison
# 49          65     1   299       NaN
# 50          58     2   405       NaN
# 51          55     2   390    Poison

# %%
pd_melted = df_grass_fire_water.melt(id_vars=['Name', 'Type 1'], value_vars=['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Stage', 'Legendary'], var_name='Melted')

pd_melted
# Out:
#            Name Type 1     Melted  value
# 0     Bulbasaur  Grass         HP     45
# 1       Ivysaur  Grass         HP     60
# 2      Venusaur  Grass         HP     80
# 3    Charmander   Fire         HP     39
# 4    Charmeleon   Fire         HP     58
# ..          ...    ...        ...    ...
# 411    Gyarados  Water  Legendary  False
# 412      Lapras  Water  Legendary  False
# 413    Vaporeon  Water  Legendary  False
# 414     Flareon   Fire  Legendary  False
# 415     Moltres   Fire  Legendary   True
#
# [416 rows x 4 columns]

# %%
# Hemos juntado en el melt 8 columnas
# https://www.statology.org/long-vs-wide-data/#:~:text=A%20dataset%20can%20be%20written,repeat%20in%20the%20first%20column.&text=Notice%20that%20in%20the%20wide,the%20first%20column%20is%20unique.

# %%
print(df_grass_fire_water.shape)
print(pd_melted.shape)
# las filas se han multiplicado por 8
# Out:
# (52, 12)
# (416, 4)

# %%
# 21. Pintamos el swarmplot con el melted y entendemos la información

# %%
sns.swarmplot(x='Melted', y='value', data=pd_melted, hue='Type 1');
# Out:
# c:\Users\alber\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\alber\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 86.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# conclusión: hemos creado una columna que contiene todos los datos que antes teníamos en varias columnas
# usamos esa columna en el X de swarmplot, así que va a pintar cada categoría de esa columna nueva
# dentro de cada categoría, pintamos cuántos puntos tenemos de cada valor Y 
# además, elegimos en hue (codificación de color) qué división de colores queremos aplicar
# por último, las categorías con valores numéricos, pintan números
# y las categorías con valores booleanos (Stage, Legendary), pintan 0 (False) y 1 (True), esto no es muy útil

# %%
# 22. Basándote en el gráfico anterior, define el tamaño de la figura en (10,6) (usa plt)
# En el swarmplot añade el argumento dodge a True y usa la anterior paleta de colores Pokemon

# Dodge en inglés es "esquivar", ¿qué diferencia ves?

# Usando plt 
# fija el límite del eje Y entre 0 y 200
# fija la leyenda con bbox_to_anchor en upper left. Pista: upper left es el código 2 y se usa el parámetro loc.

# %%
plt.figure(figsize=(10,6))
 
sns.swarmplot(x='Melted', 
              y='value', 
              data=pd_melted, 
              hue='Type 1', 
              dodge=True, 
              palette=pokemon_colores)
 
# 4. Adjust the y-axis
plt.ylim(0, 200)
 
# 5. Place legend to the right
plt.legend(bbox_to_anchor=(1, 1), loc=2)
# Out:
# c:\Users\alber\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\alber\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 10.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\alber\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 14.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\alber\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 75.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\alber\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 89.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# Observa que incluso usando Seaborn, usamos Pyplot para trabajar con los ejes, la leyenda y el tamaño
# Lo importante es que Seaborn y Pyplot conviven bien juntos

# %%
# 23. Mapas de calor
# Calcula las correlaciones del primer DataFrame original df
# Pista: las correlaciones se calculan con el método corr()
# Recuerda: las correlaciones miden entre dos variables, si varío una, cuánto me varía la otra (cómo están de relacionadas)

# %%
correladas = df.corr()
correladas
# Out:
#               Total        HP    Attack   Defense   Sp. Atk   Sp. Def  \
# Total      1.000000  0.576591  0.670939  0.508694  0.680745  0.774383
# HP         0.576591  1.000000  0.306768  0.119782  0.236649  0.490978
# Attack     0.670939  0.306768  1.000000  0.491965  0.146312  0.369069
# Defense    0.508694  0.119782  0.491965  1.000000  0.187569  0.139912
# Sp. Atk    0.680745  0.236649  0.146312  0.187569  1.000000  0.522907
# Sp. Def    0.774383  0.490978  0.369069  0.139912  0.522907  1.000000
# Speed      0.506950 -0.040939  0.194701 -0.053252  0.411516  0.392656
# Stage      0.504224  0.249207  0.361321  0.270861  0.391712  0.358308
# Legendary  0.328412  0.172441  0.147486  0.141576  0.334159  0.215314
#
#               Speed     Stage  Legendary
# Total      0.506950  0.504224   0.328412
# HP        -0.040939  0.249207   0.172441
# Attack     0.194701  0.361321   0.147486
# Defense   -0.053252  0.270861   0.141576
# Sp. Atk    0.411516  0.391712   0.334159
# Sp. Def    0.392656  0.358308   0.215314
# Speed      1.000000  0.240042   0.199969
# Stage      0.240042  1.000000  -0.142508
# Legendary  0.199969 -0.142508   1.000000

# %%
sns.heatmap(correladas);

# %%
# ¿la correlación entre qué valores se encuentra?
# la autocorrelación es la correlación de una variable consigo misma, ¿qué aprecias?
# Encuentra dos variables que veas que están fuertemente relacionadas según la correlación
# Si tuvieras una matriz de correlación muy grande y te cobrasen por cada dato que lees, ¿qué harías?

# %%
# 24. Pinta el histograma y la densidad de probabilidad del nivel de defensa usando el DataFrame original

# %%
sns.distplot(df.Defense, kde=True);
# Out:
# c:\Users\alber\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df.Defense, kde=False);
# Out:
# c:\Users\alber\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# 25. Pinta un diagrama de barras de la columna 'Type 1' usando el DataFrame original
# Usa un sns.countplot
# Usa plt.xticks y gira las etiquetas

# %%
sns.countplot(x='Type 1', data=df, palette=pokemon_colores)

plt.xticks(rotation=-45);

# %%
# 26. Usa catplot con el DataFrame original. Muestra el valor de Defense según el 'Type 1', muestra un subplot para legendarios y otro para no legendarios
# y divide los colores según el Type 2

# %%
g = sns.catplot(x='Type 1',
                y='Defense',
                data=df,
                hue='Type 2',
                col='Legendary',
                kind='swarm')

g.set_xticklabels(rotation=-45);

# %%
# 27. Muestra una función distribución de probabilidad con kdeplot (curvas de nivel) de la defensa respecto al ataque.
# Di un bin 2D donde caigan muchos puntos (ataque, defensa).

# %%
sns.kdeplot(df.Attack, df.Defense);
# Out:
# C:\Users\Daney\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# 29. Pinta una distribución de probabilidad conjunta, pintando la defensa respecto al ataque del DataFrame original

# %%
sns.jointplot(x='Attack', y='Defense', data=df);
